# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

deals = pd.read_parquet('deals.parquet')
companies = pd.read_parquet('companies.parquet')

# %% [markdown]
# # DEALS exploration

# %%
deals.head()
# Out:
#             CompanyID                              CompanyName  DealNo  \
# DealID
# 247042-45T  515209-69                          Gridflex Energy       2
# 256383-64T  593468-20  Personal Protective Equipment Business)       1
# 256415-23T  281224-09                                  Ammobia       6
# 248160-07T  314645-86                             ShiraTronics       3
# 255261-25T   61985-89  American Express Global Business Travel       9
#
#              DealDate AnnouncedDate    DealSize DealStatus DealSizeStatus  \
# DealID
# 247042-45T 2025-04-30           NaT   50.793247   Upcoming      Estimated
# 256383-64T 2025-03-31    2024-04-07  640.000000   Upcoming         Actual
# 256415-23T 2025-01-01           NaT         NaN   Upcoming           None
# 248160-07T 2024-12-31    2023-08-30         NaN   Upcoming           None
# 255261-25T 2024-12-31           NaT   71.700000   Upcoming         Actual
#
#             PremoneyValuation  PostValuation  ... Debts  DebtRaisedInRound  \
# DealID                                        ...
# 247042-45T                NaN     169.310582  ...  None                NaN
# 256383-64T                NaN     640.000000  ...  None                NaN
# 256415-23T                NaN            NaN  ...  None                NaN
# 248160-07T                NaN            NaN  ...  None                NaN
# 255261-25T                NaN            NaN  ...  None                NaN
#
#             ContingentPayout Employees             BusinessStatus  \
# DealID
# 247042-45T               NaN       NaN         Generating Revenue
# 256383-64T               NaN       NaN         Generating Revenue
# 256415-23T               NaN       NaN         Generating Revenue
# 248160-07T               NaN       NaN  Clinical Trials - General
# 255261-25T               NaN       NaN         Generating Revenue
#
#                       FinancingStatus       SiteLocation ExitScope  \
# DealID
# 247042-45T  Pending Transaction (M&A)          Boise, ID      None
# 256383-64T  Pending Transaction (M&A)       Rosewell, GA      None
# 256415-23T   Pending Transaction (VC)  San Francisco, CA      None
# 248160-07T   Pending Transaction (VC)    Minneapolis, MN      None
# 255261-25T  Pending Transaction (M&A)       New York, NY      None
#
#                                                         RowID LastUpdated
# DealID
# 247042-45T  7fbfd5b0377ea28524fb9aa29a4d7dc69b77cd4afa9313...  2024-05-07
# 256383-64T  edb67b8eea39fd78af875c8ff473c58e5fdf8a12c637ee...  2024-04-15
# 256415-23T  84cdba37bb3ae584496b965a8d9991fcecc4f14eced0ce...  2024-04-08
# 248160-07T  acd0b487f283c8afef61424303ee5aa1a851614254e55b...  2023-12-22
# 255261-25T  29a67feb98cf3ff10d6158545ed70b976df00f6e9720d2...  2024-04-22
#
# [5 rows x 39 columns]

# %%
deals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30680 entries, 247042-45T to 60266-26T
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CompanyID             30680 non-null  object
#  1   CompanyName           30680 non-null  object
#  2   DealNo                30680 non-null  int64
#  3   DealDate              29061 non-null  datetime64[ns]
#  4   AnnouncedDate         10417 non-null  datetime64[ns]
#  5   DealSize              25144 non-null  float64
#  6   DealStatus            30680 non-null  object
#  7   DealSizeStatus        24963 non-null  object
#  8   PremoneyValuation     10357 non-null  float64
#  9   PostValuation         12684 non-null  float64
#  10  PostValuationStatus   12313 non-null  object
#  11  PercentAcquired       12831 non-null  float64
#  12  RaisedToDate          25425 non-null  float64
#  13  VCRound               15295 non-null  object
#  14  VCRoundUp_Down_Flat   5633 non-null   object
#  15  TotalInvestedCapital  22402 non-null  float64
#  16  InvestorOwnership     8787 non-null   float64
#  17  StockSplit            9245 non-null   object
#  18  DealType              30680 non-null  object
#  19  DealType2             14486 non-null  object
#  20  DealType3             215 non-null    object
#  21  DealClass             30441 non-null  object
#  22  DealSynopsis          30636 non-null  object
#  23  NativeCurrencyOfDeal  30680 non-null  object
#  24  TotalInvestedEquity   17333 non-null  float64
#  25  AddOn                 30680 non-null  object
#  26  AddOnSponsors         180 non-null    object
#  27  AddOnPlatform         147 non-null    object
#  28  TotalNewDebt          4530 non-null   float64
#  29  Debts                 5943 non-null   object
#  30  DebtRaisedInRound     4533 non-null   float64
#  31  ContingentPayout      155 non-null    float64
#  32  Employees             2383 non-null   float64
#  33  BusinessStatus        30542 non-null  object
#  34  FinancingStatus       30632 non-null  object
#  35  SiteLocation          29045 non-null  object
#  36  ExitScope             2341 non-null   object
#  37  RowID                 30680 non-null  object
#  38  LastUpdated           30680 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(12), int64(1), object(23)
# memory usage: 9.4+ MB

# %%
deals.iloc[0]
# Out:
# CompanyID                                                       515209-69
# CompanyName                                               Gridflex Energy
# DealNo                                                                  2
# DealDate                                              2025-04-30 00:00:00
# AnnouncedDate                                                         NaT
# DealSize                                                        50.793247
# DealStatus                                                       Upcoming
# DealSizeStatus                                                  Estimated
# PremoneyValuation                                                     NaN
# PostValuation                                                  169.310582
# PostValuationStatus                                             Estimated
# PercentAcquired                                                      30.0
# RaisedToDate                                                          NaN
# VCRound                                                              None
# VCRoundUp_Down_Flat                                                  None
# TotalInvestedCapital                                                  NaN
# InvestorOwnership                                                     NaN
# StockSplit                                                           None
# DealType                                               Merger/Acquisition
# DealType2                                                            None
# DealType3                                                            None
# DealClass                                                       Corporate
# DealSynopsis            The company is in talks to be acquired by SK G...
# NativeCurrencyOfDeal                               South-Korean Won (KRW)
# TotalInvestedEquity                                                   NaN
# AddOn                                                                  No
# AddOnSponsors                                                        None
# AddOnPlatform                                                        None
# TotalNewDebt                                                          NaN
# Debts                                                                None
# DebtRaisedInRound                                                     NaN
# ContingentPayout                                                      NaN
# Employees                                                             NaN
# BusinessStatus                                         Generating Revenue
# FinancingStatus                                 Pending Transaction (M&A)
# SiteLocation                                                    Boise, ID
# ExitScope                                                            None
# RowID                   7fbfd5b0377ea28524fb9aa29a4d7dc69b77cd4afa9313...
# LastUpdated                                           2024-05-07 00:00:00
# Name: 247042-45T, dtype: object

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(deals.isnull(), cbar=False)
plt.title('Heatmap of Missing Values for Deals')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
deals.select_dtypes(include=['float64']).describe()
# potentially log everything but contingent payout?
# Out:
#            DealSize  PremoneyValuation  PostValuation  PercentAcquired  \
# count  25144.000000       10357.000000   12684.000000     12831.000000
# mean     171.699154         244.394620     510.766002        40.418216
# std     1305.616956        1597.796726    2773.326023        32.243923
# min        0.000033           0.013013       0.032500         0.005000
# 25%        3.000000          11.999996      19.500001        16.960000
# 50%       10.138112          31.000000      54.043151        28.570000
# 75%       47.000000         100.000000     195.000000        51.000000
# max    75400.000000       85800.000000   85800.000000       100.000000
#
#        RaisedToDate  TotalInvestedCapital  InvestorOwnership  \
# count  25425.000000          22402.000000        8787.000000
# mean     424.631197             81.529253          48.959077
# std     2613.805591            354.353021          18.988938
# min        0.001000              0.000033           0.625016
# 25%        6.000000              2.594863          34.564417
# 50%       22.890545              9.098380          48.521226
# 75%      105.250000             32.000000          62.848347
# max    79586.000000          13000.000000          99.582394
#
#        TotalInvestedEquity  TotalNewDebt  DebtRaisedInRound  ContingentPayout  \
# count         17333.000000   4530.000000        4533.000000        155.000000
# mean             46.132435    282.749208         282.578303        109.276716
# std             238.174420    682.175683         681.987544        350.034516
# min               0.001000      0.001144           0.000000          0.190000
# 25%               3.598630      2.751198           2.750000          5.278272
# 50%               9.962489     21.982500          21.800000         15.207355
# 75%              28.000000    275.461250         275.000000         75.000000
# max           12800.000000  13000.000000       13000.000000       3750.000000
#
#           Employees
# count   2383.000000
# mean     607.671842
# std     3047.778217
# min        0.000000
# 25%       10.000000
# 50%       30.000000
# 75%      140.000000
# max    61000.000000

# %%
deals['Debts'].isna().sum()
# Out:
# 24737

# %%
deals['TotalNewDebt'].describe()
# Out:
# count     4530.000000
# mean       282.749208
# std        682.175683
# min          0.001144
# 25%          2.751198
# 50%         21.982500
# 75%        275.461250
# max      13000.000000
# Name: TotalNewDebt, dtype: float64

# %%
deals['DebtRaisedInRound'].describe()
# Out:
# count     4533.000000
# mean       282.578303
# std        681.987544
# min          0.000000
# 25%          2.750000
# 50%         21.800000
# 75%        275.000000
# max      13000.000000
# Name: DebtRaisedInRound, dtype: float64

# %%
deals['DealStatus'].unique()
# Out:
# array(['Upcoming', 'Announced/In Progress', 'Completed',
#        'Failed/Cancelled', 'Rumor/Speculation', 'In Bidding Process',
#        'Postponed'], dtype=object)

# %%
deals['ExitScope'].unique()
# Out:
# array([None, 'VC EXIT', 'PE EXIT'], dtype=object)

# %%
deals['PostValuationStatus'].unique()
# Out:
# array(['Estimated', None, 'Actual'], dtype=object)

# %%
deals['NativeCurrencyOfDeal'].unique()
# Out:
# array(['South-Korean Won (KRW)', 'US Dollars (USD)',
#        'Canadian Dollars (CAD)', 'Euros (EUR)', 'Japanese Yen (JPY)',
#        'India Rupees (INR)', 'British Pounds (GBP)',
#        'Australian Dollars (AUD)', 'Chinese Yuan RMB (CNY)',
#        'Malaysian ringgit (MYR)', 'Russian Ruble (RUB)',
#        'Norwegian Krone (NOK)', 'Taiwan Dollar (TWD)',
#        'Israeli Shekels (ILS)', 'Danish Kroner (DKK)',
#        'Brazil Real (BRL)', 'South African Rand (ZAR)',
#        'Swiss Francs (CHF)', 'New Zealand Dollar (NZD)',
#        'Singapore Dollar (SGD)', 'Czech Krona (CZK)',
#        'United Arab Emirates dirham (AED)', 'Zambian Kwacha (ZMW)',
#        'Swedish Krona (SEK)'], dtype=object)

# %%
deals['PostValuationStatus'].unique()
# Out:
# array(['Estimated', None, 'Actual'], dtype=object)

# %%
deals['DealSizeStatus'].unique()
# Out:
# array(['Estimated', 'Actual', None], dtype=object)

# %%
deals['AddOn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
deals['AddOnPlatform'].unique()
# Out:
# array([None, 'Osaic', 'Emerald Technologies', 'Antero Midstream Partners',
#        'Nuance Medical', 'Benchmark Energy (Texas)',
#        'Armis (San Francisco)', 'BeyondTrust', 'Fanatics', 'Zinnia',
#        'Vallen', 'TICE Chicken Holdings', 'Shearer Supply',
#        'Road Safety Services', 'Greene Group Industries',
#        'Theodore Alexander', 'Aldinger (Dallas)', 'Level Access',
#        'Software Mind', 'MI Windows and Doors', 'IBS Software',
#        'Cameron Ashley Building Products', 'Vessco',
#        'Pacific Trellis Fruit', 'Two Circles', 'Executive Platforms',
#        'Kelso Industries', '4M Building Solutions', 'AmWINS',
#        'US LBM Holdings', 'AlpineX', 'Valsoft Corporation',
#        'Octopus Deploy', 'Madison Industries', 'FirstCall Mechanical',
#        'Frontier Dental Laboratories', 'PrimeRx', 'ExperiGreen Lawn Care',
#        'Iconic Artists Group', 'Symplr', 'Beamer',
#        'United Air Temp, Air Conditioning and Heating',
#        'Mauser Packaging Solutions', 'AHEAD', 'Instructure',
#        'Eversmith Brands', 'Superior Insurance Partners',
#        'Acxion Foodservice', 'Cordia (Arizona)', 'Rocket Shoals',
#        'Modis Dental Partners', 'Qlik Technologies',
#        'Life Time Group Holdings', 'Survitec Group',
#        'Evoque Data Center Solutions', 'RK Electric', 'OTR Solutions',
#        'Authentic Brands Group', 'Bozzetto Group',
#        'Simplicity Financial Marketing Holdings', 'Academic Partnerships',
#        'Hightower Advisors', 'Concert Golf Partners',
#        'Applied Technical Services (Georgia)',
#        'Veterinary Pharmaceutical Solutions', 'Vortex Companies',
#        'Everstory Partners', 'Cosette Pharmaceuticals', 'Chobani',
#        'Lynx Software Technologies', 'Cegeka', 'Investcorp',
#        'TrendyMinds', 'Workleap', 'Alliant Insurance Services',
#        'Young Innovations', 'World Insurance Associates',
#        'Cetera Financial Group', 'Phoenix Tower International',
#        'HealthComp', 'Sales Empowerment Group', 'Stellant Systems',
#        'Exact Care Pharmacy', 'Accurate Group', 'Exer Urgent Care',
#        'Second Nature Brands', 'Gentiva Health Services', 'Concord Music',
#        'Laborie Medical Technologies', 'Fairbanks Morse Defense',
#        'West Star Aviation', 'Kraken Oil & Gas', 'Mphasis', 'Veramed',
#        'CiTRUS Health Group', 'AirLife', 'ABC Technologies',
#        'Hub International', 'Coraltree Hospitality Group', 'HKA Global',
#        'EnergySolutions', 'litMUS Music', 'Keter Environmental Services',
#        'J&J Ventures', 'American Student Transportation Partners',
#        'Atria Wealth Solutions', 'StenTech', 'Interblock', 'Bloom Fresh',
#        'GeneFab', 'Authentic Restaurant Brands', 'Stimulus Technologies',
#        'Fender Musical Instruments', 'Self Group', 'Immedica Pharma',
#        'OMNIA Partners', 'Trintech', 'Duravant', 'Alliance Corporation',
#        'Savvy Games Group', 'Tufropes', 'Allworth Financial', 'Solenis',
#        'Ridgemar Energy', 'Accuris', 'PenLink (Nebraska)',
#        'Heartland Home Services', 'Neptune Retail Solutions', 'Desotec',
#        'RK Pharma', 'Arcadia Consumer Healthcare',
#        'Discovery Senior Living', 'Traliant', 'E78 Partners',
#        'BWC Terminals', 'Black Mountain Oil & Gas', 'WHP Global',
#        'CAM Industrial Solutions', 'Emergent Technology Holdings',
#        'Fifteenfortyseven Critical Systems Realty',
#        'Ethos Veterinary Health', 'Lineage Logistics Holdings', 'Canara',
#        'STA Group'], dtype=object)

# %%
deals['AddOnSponsors'].unique()
# Out:
# array([None, 'ACE & Company, Reverence Capital Partners',
#        'Crestview Partners', 'Yorktown Partners',
#        'MD Holdings, Medallion Capital, The Operand Group, WSC & Company',
#        'McArron Partners',
#        'Brookfield Growth, CapitalG, Georgian, Insight Partners, One Equity Partners, Pantheon, Pennsylvania Public School Employees Retirement System, StepStone Group, Temasek Holdings',
#        'Clearlake Capital Group, Francisco Partners, NB Private Equity Partners, Olam Capital',
#        'Ames Watson, Andreessen Horowitz, BlackRock, Blackstone, Clearlake Capital Group, DFO Management, Fidelity Investments, Fidelity Management & Research, Franklin Templeton, Franklin Venture Partners, Insight Partners, Intersection Growth Partners, LionTree, Loka Capital, Neuberger Berman, Qatar Investment Authority, Reimagined Ventures, Silver Lake, SoftBank Investment Advisers, Thrive Capital',
#        'Eldridge Industries', 'Nautic Partners', 'AIM Associates Capital',
#        'Investcorp, PNC Riverarch Capital', 'Harvest Partners', 'Tinicum',
#        'Turn Capital', 'Incline Equity Partners',
#        'JMI Equity, Kohlberg Kravis Roberts', 'Enterprise Investors',
#        'Koch Equity Development', 'Apax Partners',
#        'Highland Avenue Capital Funds, Pacific Avenue Capital Partners',
#        'Gryphon Investors', 'Arable Capital Partners',
#        'Charterhouse Capital Partners', 'Falfurrias Capital Partners',
#        'Oxbow Equity Partners, Paceline Equity Partners, Peterson Partners',
#        'O2 Investment Partners', 'Renovo Capital',
#        'Dragoneer Investment Group, Genstar Capital, Public Sector Pension Investment Board, SkyKnight Capital',
#        'Bain Capital, Ergo Partners, Platinum Equity', 'Alpine Investors',
#        'Coatue Management, Viking Global Investors',
#        'Insight Partners, Newtopia VC', 'Barings, Sequoia Heritage',
#        'SkyKnight Capital', 'TA Associates Management', 'Huron Capital',
#        'HPS Investment Partners',
#        "Brookfield Growth, California Public Employees' Retirement System, CapitalG, Georgian, Insight Partners, One Equity Partners, Pantheon, Pennsylvania Public School Employees Retirement System, Temasek Holdings, Yale University",
#        'Charlesbank Capital Partners, Clearlake Capital Group, Dallas Venture Partners, Electa Ventures, ESAS Holding, First Trust Capital Partners, Jupiter Peak, SkyKnight Capital',
#        'Camber Partners (San Francisco)',
#        'Capitala Group, Pareto & Company, Summit Park',
#        "ACE & Company, Arcadia Investment Partners, CFT Capital Partners, Ontario Teachers' Pension Plan, Stone Canyon Industries",
#        'Berkshire Partners, Centerbridge Partners', 'Thoma Bravo',
#        'The Riverside Company', "Tyree & D'Angelo Partners",
#        'Ares Capital Corporation BDC, Prospect Hill Growth Partners',
#        'Kohlberg Kravis Roberts', 'AE Industrial Partners',
#        'Thurston Group (Chicago)', 'CPP Investments, Thoma Bravo',
#        'Fisher Lynch Capital, Leonard Green & Partners, TPG',
#        'CQS (Asset Management), M&G, Searchlight Capital Partners',
#        'Brookfield Infrastructure Partners',
#        'Sope Creek, Summit Partners',
#        'BlackRock Private Equity Partners, CVC Capital Partners, General Atlantic, GIC (Singapore), HPS Investment Partners, Jasper Ridge Partners, Leonard Green & Partners, Lion Capital',
#        'Aimia, Paladin (US)', 'Lee Equity Partners',
#        'Ascension Ventures, Atlantic Merchant Capital Investors, Claritas Capital, Finback Investment Partners, Vistria Group',
#        'Coller Capital, Goldman Sachs Asset Management, Neuberger Berman, SEB Private Equity, Thomas H. Lee Partners',
#        'Centroid Investment Partners, Clearlake Capital Group',
#        'Odyssey Investment Partners, PennantPark Floating Rate Capital BDC',
#        'Granite Creek Capital Partners, Pouilly Investment Co.',
#        'Quad-C Management, Vellano Investment', 'Axar Capital',
#        'Arlington Capital Partners', 'Avista Capital Partners',
#        'Healthcare of Ontario Pension Plan', 'OceanSound Partners',
#        'Gimv, Noshaq',
#        'Kuwait Investment Authority, Mamoura Diversified Global Holding',
#        'Contour Ridge, Genesis Park',
#        'Caisse de dépôt et placement du Québec',
#        'Auburn Hill Capital, Public Sector Pension Investment Board, Stone Point Capital',
#        'The Jordan Company',
#        'Charlesbank Capital Partners, Goldman Sachs Asset Management',
#        'Genstar Capital, Parthenon Capital Partners',
#        'Blackstone, Wren House Infrastructure',
#        'Blackstone, Eir Partners, New Mountain Capital',
#        'RFE Investment Partners', 'Novacap', 'Orangewood Partners',
#        'CapVest Partners', 'Clayton, Dubilier & Rice',
#        'Great Mountain Partners', 'Patricia Industries',
#        'Arcline (Private Equity)', 'The Sterling Group',
#        'Kayne Anderson Capital Advisors',
#        'Abu Dhabi Investment Authority, Blackstone, GIC (Singapore), UC Investments',
#        'Livingbridge', 'NaviMed Capital',
#        'A&M Capital, Dempsey Ventures, Frazier Healthcare Partners',
#        'Apollo Global Management, Brookfield Oaktree Holdings',
#        'Altas Partners, Blackstone, Finback Investment Partners, Hellman & Friedman, Leonard Green & Partners',
#        'Lowe (United States)', 'PAI Partners',
#        'Dobbs Management Service, Stephens, TriArtisan Capital Advisors',
#        'The Carlyle Group', 'Alberta Investment Management, TPG',
#        'Brookfield Oaktree Holdings', 'Access Holdings',
#        'Verde Equity Partners', 'Five Points Capital, NaviMed Capital',
#        'Align Capital Partners', 'EQT, Paine Schwartz Partners',
#        'Celadon Partners',
#        'Garnett Station Partners, Oxford Financial Group',
#        'Servco Pacific Capital', 'Friulia Finanziaria FVG', 'Impilo',
#        'AustralianSuper, Claritas Capital, Leonard Green & Partners, TA Associates Management',
#        'Summit Partners, Vista Equity Partners',
#        'The Carlyle Group, Warburg Pincus',
#        'Lee Equity Partners, Twin Point Capital',
#        "Saudi Arabia's Public Investment Fund", 'Paladin (US)',
#        "Lightyear Capital, Ontario Teachers' Pension Plan",
#        'Platinum Equity', 'Carnelian Energy Capital', 'Spire Capital',
#        'Cobepa, The Jordan Company', 'Charlesbank Capital Partners',
#        'Blackstone, EQT', 'PAG',
#        'Bansk Group, Constitution Capital Partners',
#        'Martinson Ventures, PSG',
#        'Churchill Asset Management, Further Global Capital Management, Thurston Group (Chicago)',
#        'JP Morgan Asset Management',
#        'NGP Energy Capital Management, Trace Capital Management',
#        'Ares Private Equity Group, Brookfield Oaktree Holdings, Express',
#        'Cross Rapids Capital, The Baupost Group',
#        'Aurin Investment Group',
#        'Branford Castle Partners, Cerberus Capital Management, Drum Capital Management',
#        'Atalaya Capital Management, Valterra Partners',
#        'American Securities', 'JAB Holding Company',
#        'Bay Grove Capital, D1 Capital Partners, Echelon Capital (Seattle), Stonepeak',
#        'Mayfair Equity Partners', 'Columbia Capital',
#        'Apollo Global Management',
#        'Ally Bridge Group, CVF Capital Partners, General Atlantic, OrbiMed, Perceptive Advisors, SEB Private Equity, Themes Investment Partners',
#        'Blackstone, Greystar Real Estate Partners', 'Dillon Kane Group',
#        'Blackstone', 'GTCR', 'TPG', 'Lone Star Funds', 'Geolo Capital',
#        'Silver Lake',
#        'NGP Energy Capital Management, NGP Energy Technology Partners',
#        'Palladium Equity Partners',
#        'Stone River Capital Partners, Wynnchurch Capital',
#        'Helios Capital, Ranieri Partners, WL Ross & Co.',
#        'AlpInvest Partners, Capital Management and Investment, Keystone Group (Texas), Modulaire Group, The Cypress Group',
#        'Cevian Capital, Harbinger Capital Partners',
#        'Riveria Investment Group', 'Providence Equity Partners',
#        'Patriot Capital Funding, Reliant Equity Investors',
#        'Bruckmann, Rosser, Sherrill & Company',
#        'Bridgepoint Advisers, Stirling Square Capital Partners',
#        'Lincolnshire Management',
#        'CCMP Capital Advisors, Lexington Partners, The Cypress Group'],
#       dtype=object)

# %%
deals['BusinessStatus'].unique()
# Out:
# array(['Generating Revenue', 'Clinical Trials - General', 'Profitable',
#        None, 'Startup', 'Product In Beta Test', 'Pre-Clinical Trials',
#        'Generating Revenue/Not Profitable', 'Clinical Trials - Phase 3',
#        'Clinical Trials - Phase 2', 'Bankruptcy: Admin/Reorg',
#        'Product Development', 'Out of Business', 'Stealth',
#        'Clinical Trials - Phase 1', 'Bankruptcy: Liquidation', 'Restart',
#        'Clinical Trials - Phase 4'], dtype=object)

# %%
deals['FinancingStatus'].unique()
# Out:
# array(['Pending Transaction (M&A)', 'Pending Transaction (VC)',
#        'Pending Transaction (PE)', 'Corporation',
#        'Venture Capital-Backed', 'Formerly VC-backed',
#        'Private Equity-Backed', 'Corporate Backed or Acquired',
#        'Formerly PE-Backed', 'Failed Transaction (M&A)',
#        'Formerly Angel backed', 'Private Debt Financed',
#        'Formerly Private Debt Financed', 'Pending Transaction (Debt)',
#        'Formerly Accelerator/Incubator backed',
#        'Pending Transaction (Angel)', None, 'Angel-Backed',
#        'Failed Transaction (PE)', 'Accelerator/Incubator Backed',
#        'Failed Transaction (VC)', 'Potential Target',
#        'Failed Transaction (Angel)'], dtype=object)

# %%
deals['StockSplit'].unique()
# Out:
# array([None, '1:1', '3:1', '100:1', '10:1', '1:20', '1:16.667', '1:9',
#        '1:2', '30:1', '500:1', '1000:1', '1:4', '4:1', '1:5', '13.5685:1',
#        '5:1', '1:1.2', '1:5.141', '1:6', '1:3.922668', '1:100', '1:6.82',
#        '1:24752441', '1:0.713506', '1:3', '1:5.6955', '1:50', '3.4:1',
#        '1:40', '20:1', '50:1', '1:22', '1:17', '1:15.969236', '1:9.5',
#        '2.300313:1', '2.88:1', '445:1', '1:2.432', '1300000:1',
#        '1:2.5161', '1:1.581804', '1.8249:1', '1:7.039', '1:500', '1:250',
#        '1:6.178', '1:1.23453', '0.168466:1', '1.68:1', '1:9.3197',
#        '1:13.9549', '1:8.4335', '1:3.55092', '1:1.247', '1:2.1095',
#        '1:700', '1:34.483', '1:2.1703', '1:12', '1:6.6084', '1:4.7',
#        '1:8', '661500:1', '1:1.2987', '1:9.1908', '55.2486:1',
#        '1.534387:1', '1:12.2', '1:4.9175', '1:4.5', '1:10', '1.2:1',
#        '0.7378:1', '9:1', '1:3.29', '2:1', '1:2.33839', '1:2.58398',
#        '2.2:1', '6.684195:1', '237:1', '2.6975:1', '1:3.75', '1:200',
#        '709977:1', '26.9576:1', '1:9.937', '1:1.728107', '1:1.94',
#        '1:1.45', '12.345679:1', '1:10.5', '1:18', '1:28', '2.5:1',
#        '1:2.3', '1:1.88', '1:25.4588', '1.9845:1', '1:25.4', '1:30',
#        '10.98:1', '1:8.45', '1:1000', '70:1', '1:2.64', '1:3.5', '1:5.9',
#        '1:32', '1:5.7778', '5.25:1', '1:3.92', '3403.453:1', '1:11.288',
#        '1:662.07889', '1:1.769191', '1:1.3', '1:20.75281', '30000:1',
#        '3:2', '1:2.2881', '0.55:1'], dtype=object)

# %%
deals['VCRound'].unique()
# Out:
# array([None, '2nd Round', '3rd Round', '4th Round', '1st Round', 'Angel',
#        '7th Round', '6th Round', '5th Round', '8th Round', '9th Round',
#        '10th Round', '11th Round', '15th Round', '12th Round',
#        '14th Round', '13th Round', '17th Round', '16th Round'],
#       dtype=object)

# %%
deals['VCRoundUp_Down_Flat'].unique()
# Out:
# array([None, 'Down Round', 'Up Round', 'Flat Round'], dtype=object)

# %%
deals['DealSynopsis'].iloc[0]
# maybe scrape this information? check if useful
# Out:
# 'The company is in talks to be acquired by SK Gas (KRX: 018670) for $69.7 billion on December 6, 2023. This acquisition will utilize the trading capabilities SK Gas has accumulated so far to conduct ESS-based power trading.'

# %%
deals['DealClass'].unique()
# try both one-hot and labels? check if there's ordinality
# Out:
# array(['Corporate', 'Venture Capital', 'Private Equity', 'Debt',
#        'Individual', 'Other', 'Public Investment', 'Bankruptcy',
#        'Out of Business', None, 'Hedge Fund'], dtype=object)

# %%
deals['DealType'].unique()
# more detailed ver of dealclass?
# Out:
# array(['Merger/Acquisition', 'Early Stage VC', 'Later Stage VC', 'PIPE',
#        'Buyout/LBO', 'Debt - General', 'Seed Round', 'Angel (individual)',
#        'Grant', 'IPO', 'Debt Refinancing', 'PE Growth/Expansion',
#        'Public Investment 2nd Offering', 'Reverse Merger',
#        'Bankruptcy: Admin/Reorg', 'Corporate', 'Out of Business',
#        'Accelerator/Incubator', 'Secondary Transaction - Open Market',
#        'Mezzanine', 'Dividend Recapitalization',
#        'Secondary Transaction - Private', 'Equity Crowdfunding',
#        'Leveraged Recapitalization', 'Spin-Off',
#        'Bankruptcy: Liquidation', 'GP Stakes', 'Sale-Lease back facility',
#        'Debt Repayment', 'Share Repurchase', 'Restart - Later VC',
#        'Joint Venture', 'Platform Creation', 'Product Crowdfunding',
#        'Corporate Asset Purchase', 'Capitalization', 'Debt - PPP',
#        'Merger of Equals', 'Debt Conversion', 'Undetermined',
#        'Restart - Early VC', 'Secondary Transaction - Stock Distribution',
#        'Convertible Debt', 'Dividend', 'Investor Buyout by Management'],
#       dtype=object)

# %%
deals[deals['DealClass'].isnull()]['DealType'].unique()
# Out:
# array(['Secondary Transaction - Open Market', 'PIPE', 'Seed Round',
#        'Secondary Transaction - Private', 'Grant', 'Platform Creation'],
#       dtype=object)

# %%
deals[deals['DealType'] == 'PIPE'][['DealClass']]
# Out:
#                   DealClass
# DealID
# 255261-25T        Corporate
# 258688-81T        Corporate
# 257984-20T        Corporate
# 258572-26T   Private Equity
# 258489-82T        Corporate
# ...                     ...
# 48856-51T   Venture Capital
# 29729-17T         Corporate
# 184289-68T        Corporate
# 102101-05T             None
# 101400-94T   Private Equity
#
# [1246 rows x 1 columns]

# %%
deals['DealType2'].unique()
# Out:
# array([None, 'Corporate Divestiture', 'Series A', 'Seed Round',
#        'Public to Private', 'Angel (individual)', 'Add-on', 'Series B',
#        'Series C', 'Series E', 'Acquisition Financing', 'Series A3',
#        'Secondary Buyout', 'Series 1', 'Series B1', 'Series F',
#        'Series D', 'Series A1', 'Project Financing', 'Series A2',
#        'Asset Acquisition', 'Capital Spending', 'Series 2', 'Corporate',
#        'Series C1', 'Series BB', 'Series C2', 'Series B2',
#        'Dividend Recapitalization', 'Spin-Off', 'Debtor-In-Possession',
#        'Series AA', 'Series G', 'Series B3', 'Debt - General', 'Series 3',
#        'Distressed Acquisition', 'Management Buyout', 'Series D2',
#        'Series C3', 'Carveout', 'Series AAA', 'Series D1',
#        'Management Buy-In', 'Recapitalization', 'Series I', 'Series E1',
#        'Debt Refinancing', 'Series H', 'Series CC', 'Series DD', 'Bonds',
#        'Mezzanine', 'Series D3', 'Series E2', 'Convertible Debt',
#        'Debt Refinance', 'PIPE', 'Series J', 'Loan', 'Debt Conversion',
#        'Subordinated Debt', 'Secured Debt', 'Exit Financing',
#        'Debt Repayment', 'Revolving Credit Line', 'Unsecured Debt',
#        'Senior Debt, Secured', 'Senior Debt', 'Dividend', 'Series K',
#        'Bridge'], dtype=object)

# %%
deals['DealType3'].unique()
# only 200+ non nulls, probs drop
# Out:
# array([None, 'Corporate Divestiture', 'Recapitalization', 'Add-on',
#        'Asset Divestiture (Corporate)', 'Public to Private',
#        'Secondary Buyout', 'Leveraged Recapitalization',
#        'Acquisition Financing', 'Management Buyout', 'Secured Debt',
#        'Distressed Acquisition'], dtype=object)

# %%
deals['Debts'].nunique()
# Out:
# 3643

# %%
sns.kdeplot(data = deals, x = 'PostValuation')
# Out:
# /Users/peiyuanlee/miniforge3/envs/myenv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PostValuation', ylabel='Density'>

# %% [markdown]
# # Companies exploration

# %%
companies.info()
# keep -> companyname, description, keywords, companyfinancingstatus, '' date, employees, year founded, parentcompany, '' id?, 
# companies = companies[['CompanyName', 'Keywords', 'CompanyFinancingStatus', 'CompanyFinancingStatusDate', 'BusinessStatus', ]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6487 entries, 10022-68 to 596978-56
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CompanyName                  6487 non-null   object
#  1   CompanyAlsoKnownAs           2767 non-null   object
#  2   CompanyFormerName            1536 non-null   object
#  3   CompanyLegalName             6036 non-null   object
#  4   Description                  6482 non-null   object
#  5   Keywords                     6484 non-null   object
#  6   CompanyFinancingStatus       6487 non-null   object
#  7   CompanyFinancingStatusDate   6336 non-null   object
#  8   TotalRaised                  5483 non-null   float64
#  9   TotalRaisedNativeAmount      5471 non-null   float64
#  10  TotalRaisedNativeCurrency    5483 non-null   object
#  11  BusinessStatus               6451 non-null   object
#  12  BusinessStatusDate           6451 non-null   object
#  13  OwnershipStatus              6487 non-null   object
#  14  OwnershipStatusDate          6486 non-null   object
#  15  Universe                     6487 non-null   object
#  16  Website                      6158 non-null   object
#  17  Employees                    5718 non-null   float64
#  18  EmployeeAsOfDate             5718 non-null   object
#  19  DescriptionShort             6486 non-null   object
#  20  Exchange                     526 non-null    object
#  21  Ticker                       523 non-null    object
#  22  YearFounded                  6105 non-null   float64
#  23  ParentCompany                823 non-null    object
#  24  ParentCompanyID              823 non-null    object
#  25  FinancingStatusNote          6486 non-null   object
#  26  FinancingStatusNoteAsOfDate  6481 non-null   object
#  27  FacebookProfileURL           3393 non-null   object
#  28  TwitterProfileURL            4445 non-null   object
#  29  LinkedInProfileURL           5662 non-null   object
#  30  PrimaryContactPBId           6013 non-null   object
#  31  PrimaryContactFirstName      6013 non-null   object
#  32  PrimaryContactLastName       6013 non-null   object
#  33  PrimaryContactMiddle         1263 non-null   object
#  34  PrimaryContactPrefix         5966 non-null   object
#  35  PrimaryContactSuffix         969 non-null    object
#  36  PrimaryContact               6013 non-null   object
#  37  PrimaryContactTitle          6013 non-null   object
#  38  RowID                        6487 non-null   object
#  39  LastUpdated                  6487 non-null   object
# dtypes: float64(4), object(36)
# memory usage: 2.0+ MB

# %%
companies.head()
# Out:
#                     CompanyName CompanyAlsoKnownAs CompanyFormerName  \
# CompanyID
# 10022-68         Boart Longyear               None              None
# 10026-37    Greenhill & Company          Greenhill              None
# 10049-68     Kohlberg & Company           Kohlberg              None
# 10057-15     Corner Bakery Cafe                CBC              None
# 10058-41   Angelo, Gordon & Co.  TPG Angelo Gordon              None
#
#                      CompanyLegalName  \
# CompanyID
# 10022-68          Boart Longyear Ltd.
# 10026-37         Greenhill & Co, Inc.
# 10049-68       Kohlberg & Co., L.L.C.
# 10057-15   CBC Restaurant Corporation
# 10058-41    Angelo, Gordon & Co. L.P.
#
#                                                  Description  \
# CompanyID
# 10022-68   Boart Longyear Ltd is a U.S.-based ASX-listed ...
# 10026-37   Greenhill & Co Inc is an independent investmen...
# 10049-68   Operator of a private equity firm intended to ...
# 10057-15   Owner and operator of a chain of cafes serving...
# 10058-41   Provider of alternative investment strategies ...
#
#                                                     Keywords  \
# CompanyID
# 10022-68   contract drilling service, down-hole instrumen...
# 10026-37   financial advice, financings and capital raisi...
# 10049-68   add-on acquisition, growth capital, pe firm, p...
# 10057-15   bakery cookies, bakery food items, bakery mixi...
# 10058-41   alternative investment, fund management, inves...
#
#                  CompanyFinancingStatus CompanyFinancingStatusDate  \
# CompanyID
# 10022-68          Private Equity-Backed                 04/10/2024
# 10026-37   Corporate Backed or Acquired                 12/01/2023
# 10049-68         Venture Capital-Backed                 09/05/2023
# 10057-15             Formerly PE-Backed                 06/08/2023
# 10058-41   Corporate Backed or Acquired                 11/01/2023
#
#            TotalRaised  TotalRaisedNativeAmount  ... PrimaryContactPBId  \
# CompanyID                                        ...
# 10022-68   3027.643662              3027.643662  ...          64236-52P
# 10026-37    832.500000               832.500000  ...          15456-79P
# 10049-68     12.196849                12.196849  ...         299670-85P
# 10057-15      2.551000                 2.551000  ...         219818-17P
# 10058-41           NaN                      NaN  ...          11481-85P
#
#           PrimaryContactFirstName PrimaryContactLastName PrimaryContactMiddle  \
# CompanyID
# 10022-68                  Jeffrey                  Olsen                 None
# 10026-37                  Gregory               Randolph                   G.
# 10049-68                   Marina                 Chalik                 None
# 10057-15                     Yeet                    Yah                 None
# 10058-41                  Michael                 Gordon                   L.
#
#           PrimaryContactPrefix PrimaryContactSuffix     PrimaryContact  \
# CompanyID
# 10022-68                   Mr.                 None      Jeffrey Olsen
# 10026-37                   Mr.                 None   Gregory Randolph
# 10049-68                   Ms.                 None      Marina Chalik
# 10057-15                   Ms.                 None           Yeet Yah
# 10058-41                   Mr.                   JD  Michael Gordon JD
#
#                                          PrimaryContactTitle  \
# CompanyID
# 10022-68   President, Chief Executive Officer and Board M...
# 10026-37                                   Managing Director
# 10049-68                   Vice President, Investor Services
# 10057-15                             Chief Financial Officer
# 10058-41   Co-Founder and non-Executive Chairperson of Pa...
#
#                                                        RowID LastUpdated
# CompanyID
# 10022-68   d1f91d5975321ea1e186f197e4d465ab0fde607f532726...  04/20/2024
# 10026-37   47610123c0f0a724b969bafff9325467dd90cf21f16100...  03/23/2024
# 10049-68   e2b674922c9d7df7c56ed00c0bbe9ebaa9bcf1916e3604...  03/06/2024
# 10057-15   8bb38b598aa57b4f1bb127871327f03f5f76d36a4eddbc...  12/12/2023
# 10058-41   71c4890f48e4b74f9363d5b9403bc2186245f3e9f97992...  05/07/2024
#
# [5 rows x 40 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(companies.isnull(), cbar=True)
plt.title('Heatmap of Missing Values for Companies')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
companies.select_dtypes(include=['float64']).describe()
# Out:
#         TotalRaised  TotalRaisedNativeAmount      Employees  YearFounded
# count   5483.000000              5471.000000    5718.000000  6105.000000
# mean     252.004860               260.140719     608.115600  2010.093202
# std     1699.408349              1736.271283    6361.911993    20.855640
# min        0.010000                 0.010000       2.000000  1826.000000
# 25%       12.492352                12.492352      19.000000  2011.000000
# 50%       32.300000                32.364995      45.000000  2017.000000
# 75%      104.639989               104.884997     130.000000  2020.000000
# max    79586.000000             79586.000000  400000.000000  2024.000000

# %%
companies['Universe'].unique()
# Out:
# array(['Debt Financed, Private Equity, Publicly Listed',
#        'Debt Financed, M&A, Publicly Listed',
#        'Private Equity, Venture Capital', 'Debt Financed, Private Equity',
#        'M&A', 'Debt Financed, M&A, Private Equity, Publicly Listed',
#        'Debt Financed, M&A, Private Equity', 'M&A, Private Equity',
#        'Private Equity',
#        'Debt Financed, M&A, Private Equity, Publicly Listed, Venture Capital',
#        'M&A, Publicly Listed',
#        'Debt Financed, Private Equity, Publicly Listed, Venture Capital',
#        'Debt Financed, Private Equity, Venture Capital',
#        'M&A, Private Equity, Publicly Listed', 'M&A, Venture Capital',
#        'Debt Financed, Publicly Listed',
#        'Debt Financed, Publicly Listed, Venture Capital',
#        'Private Equity, Publicly Listed',
#        'Debt Financed, Venture Capital', 'Venture Capital',
#        'Debt Financed, M&A, Publicly Listed, Venture Capital',
#        'Private Equity, Publicly Listed, Venture Capital',
#        'Debt Financed, M&A, Venture Capital',
#        'Publicly Listed, Venture Capital', 'Publicly Listed',
#        'M&A, Publicly Listed, Venture Capital',
#        'M&A, Private Equity, Publicly Listed, Venture Capital',
#        'Debt Financed, M&A, Private Equity, Venture Capital',
#        'M&A, Private Equity, Venture Capital', 'Debt Financed, M&A',
#        'Debt Financed, Pre-venture', 'Pre-venture',
#        'M&A, Pre-venture, Publicly Listed',
#        'Pre-venture, Venture Capital',
#        'Debt Financed, Pre-venture, Publicly Listed',
#        'Other Private Companies',
#        'Debt Financed, Pre-venture, Private Equity',
#        'Pre-venture, Publicly Listed'], dtype=object)

# %%
companies.iloc[0]['DescriptionShort']
# Out:
# 'Manufacturer of drilling equipment and performance tools intended for mining and drilling companies.'

# %%
companies.iloc[0]['Keywords'] # maybe provide information about industry? debts cap
# Out:
# 'contract drilling service, down-hole instrumentation, drilling equipment, drilling service, integrated drilling, mine dewatering, production drilling'

# %%
companies.iloc[0]['Description'] # drop this maybe, provides same info as descriptionshort and keywords
# Out:
# 'Boart Longyear Ltd is a U.S.-based ASX-listed company with large market shares in the Global mineral drilling services and drilling equipment industries. The company operates two divisions: Global Drilling Services and Global Products. The Global Drilling Services division that derives the majority revenue operates for a diverse mining customer base spanning a wide range of commodities, including copper, gold, nickel, zinc, uranium, and other metals and minerals. The Global Products division designs, manufactures and sells drilling equipment, performance tooling, down-hole instrumentation, and parts and services.'

# %%
companies['OwnershipStatus'].unique()
# Out:
# array(['Privately Held (backing)', 'Publicly Held',
#        'Acquired/Merged (Operating Subsidiary)', 'Acquired/Merged',
#        'In IPO Registration', 'Privately Held (no backing)',
#        'Out of Business'], dtype=object)

# %%
companies['Ticker'].unique()
# Out:
# array([None, 'SN', 'HA', 'SAVE', 'CNGO', 'EGIO', 'USB', 'NRG', 'LXRX',
#        'BV', 'CODI', 'SLCA', 'DOOR', 'LL', 'SVV', 'LGF.B', 'HRT', 'SATS',
#        'APHD', 'THRY', 'ANSS', 'TAST', 'BTSG', 'NSC', 'PNM', 'OXY', 'PTC',
#        'X', 'RAIL', 'HAYN', 'MODN', 'CNSL', 'STER', 'BATL', 'JNPR',
#        'SEAC', 'HIBB', 'MIMOQ', 'SIX', 'IRBT', 'DFS', 'CMTL', 'AMED',
#        'NI', 'BSY', 'PRFT', 'OCUL', 'SNDA', 'CYTH', 'LCTX', 'ASTC',
#        'HRTX', 'AIRC', 'SCX', 'MCBC', 'PBI', 'ABCP', 'PAR', 'CRK', 'SWN',
#        'SCND', 'AMNB', 'SHEN', 'VLY', 'MGRC', 'NYCB', 'HTLF', 'NNUP',
#        'INRD', 'FNCB', 'VASO', 'NWLI', 'FRBK', 'CVLY', 'WIRE', 'NKTR',
#        'TTNP', 'ALE', 'SP', 'DCTH', 'BCLI', 'SSNT', 'LUNA', 'TLRS',
#        'TTGT', 'E1BP', 'NLST', 'XTNT', 'FUN', 'CATX', 'AIAD', 'AWH',
#        'CYCC', 'PSTV', 'CLRB', 'FFNW', 'SGMT', 'RCM', 'WKHS', 'EVFM',
#        'OCX', 'MDBH', 'CALB', 'AGLX', 'TYGO', 'COSM', 'FG', 'IBIO',
#        'NSTGQ', 'BDSX', 'TLPH', 'VZIO', '445680', 'MARA', 'KPRX', 'LCID',
#        'VTVT', 'TGAN', 'ALTI', 'CTCX', 'HMST', 'TOON', 'PRST', 'EVBG',
#        'VRDN', 'CRIS', 'EDR', 'HOOK', 'IMPLQ', 'LYRA', 'ALRN', 'AGBA',
#        'DTI', 'MTEM', 'RDDT', 'GCTK', 'ELDN', 'GMDAQ', 'SSYS', 'KA',
#        'LOAR', 'PSX', 'GUTS', 'KALV', 'RGLS', 'MTTR', 'BLND', 'CART',
#        'DRIO', 'IBTA', 'COIN', 'ULS', 'SPIR', 'AMK', 'TH', 'INBX', 'EFTR',
#        'URGN', 'REXR', 'AGFY', 'BIOR', 'ZFOX', 'ARVN', 'ADTH', 'AUUD',
#        'SWAV', 'VYNE', 'OWLT', 'ZEVY', 'NOTE', 'CAVA', 'ECOR', 'HCP',
#        'SNPO', 'BNTC', 'CRTA', 'ENSU', 'CSKL', 'CATC', 'FGBI', 'TSBA',
#        'BRBS', 'MSVB', 'ACST', 'IBAT', 'DMAC', 'SGN', 'EU', 'ADVM',
#        'AVTX', 'HES', 'BANC', 'CTLT', 'RNXT', 'VIK', 'MFH', 'APRE',
#        'GWAV', 'GH', 'INTS', 'HEPA', 'RNA', 'ALU', 'GBTG', 'VMEO', 'AXNX',
#        'CELC', 'GROV', 'NERV', 'ULY', 'CDTX', 'CBUS', 'DSKE', 'KORE',
#        'GWH', 'DCPH', 'SDPI', 'OTLK', 'DNMR', 'CGON', 'GNLX', 'SCLX',
#        'VSTO', 'CVNA', 'KVYO', 'CDE', 'GWBK', 'MMM', 'GNPX', 'CAST',
#        'IGMS', 'NAOV', 'CBST', 'FREE', 'CRBU', 'NEXT', 'COGT', 'ENL',
#        'AMIX', 'AZTR', 'SKYE', 'QTI', 'RKLB', 'AJX', 'CHX', 'KGS', 'CURA',
#        'IBRX', 'RXRX', 'BEEP', 'KURA', 'ALPN', 'WH', 'CRNX', 'RBRK',
#        'AUID', 'GRI', 'NTRB', 'SLE', 'ORIC', 'DNLI', 'TBLD', 'LTRY',
#        'AKOM', 'SLS', 'BNED', 'LLAP', 'FFIE', 'MPIR', 'WRK', 'SNES',
#        'SFRT', 'ACMR', 'AFT', 'BETR', 'DM', 'TSBX', 'TRUG', 'SLDB',
#        'ELUT', 'WRIV', 'CHRO', 'SMXT', 'CTRI', 'ELIQ', 'SHIM', 'MCHN',
#        'NBBK', 'OLMA', 'PACS', 'NVNO', 'PSTX', 'BTTX', 'CCCC', 'ACLX',
#        'LPTX', 'CKPT', 'WEX', 'VERX', 'EYEN', 'RCUS', 'RDZN', 'LENZ',
#        'KROS', 'CRML', 'XLO', 'FLYX', 'BENF', 'BBIO', 'RLAY', 'IMUX',
#        'MGTX', 'SRZN', 'AREN', 'NPWR', 'DOMA', 'ACHV', 'AEVA', 'APLT',
#        'OPTX', 'SABS', 'CERO', 'TNGX', 'MP', 'ODD', 'PTPI', 'EVTS', 'WAM',
#        'WRAP', 'YS', 'COSO', 'FEAM', 'KRYS', 'HGTY', 'CELU', '6976',
#        'LABP', 'SRM', 'CGEM', 'XFLT', 'NRXS', 'GOSS', 'TARA', 'AYRO',
#        'BTAI', 'ALTM', 'UNCY', 'CORZ', 'GOEV', 'ASTS', 'MNR', 'CTNM',
#        'INAB', 'PBNC', 'MAMO', 'PNST', 'GANX', 'ASTR', 'ANL', 'STSS',
#        'SXTP', 'CERE', 'AAWH.U', 'ALGS', 'MIRM', 'ETRN', 'ERAS', 'MSBB',
#        'TBIO', 'LRHC', 'ADTX', 'NBSE', 'ALAB', 'NGNE', 'ZONE', 'CLDI',
#        'VERY', 'GPCR', 'KRRO', 'AEON', 'EICCF', 'IPSC', 'INBS', 'PYXS',
#        'MNMD', 'BTM', 'IMVT', 'GLAS.A.U', 'MGX', 'AONC', 'TYRA', 'BOLD',
#        'ACRV', 'DNTH', 'ODII', 'KYTX', 'ANRO', 'VERS', 'FA', 'WEST',
#        'SDHC', 'CFIC', 'TBNK', 'PFSB', 'LUNR', 'SUG', 'ECDA', 'AHR',
#        'ELYM', 'MOVE', 'BNZI', 'FBRX', 'CLRD', 'TSHA', 'MSDL', 'VTYX',
#        'NKGN', 'SHOT', 'GREE', 'JTAI', 'ACHR', 'TECX', 'JNVR', 'MOBX',
#        'IPX', 'VLCN', 'NMRA', 'GRAM', 'ELVN', 'TRYPF', 'LXEO', 'GPAC',
#        'COYA', 'CVII', 'TWLV', 'MBTC', 'PLMI', 'MLYS', 'WALD', 'VXTR',
#        'SERV', 'IAU', 'BOF', 'FRLA', 'SDIG', 'CRGX', 'INTE', 'AVBP',
#        'BFRI', 'CCTS', 'SKYH', 'VHAI', 'PSBD', 'MCAA', 'SOAR', 'BACA',
#        'TMTC', 'ELAB', 'RR', 'USCTF', 'ANSC', 'DJT', 'BOCN', 'SCRM',
#        'UMAC', 'PSQH', 'HYAC', 'RWOD', 'ISRL', 'AIMBU', 'AIRJ', 'BTTC',
#        'IVP', 'SYRA', 'SKGR', 'ESHA', 'ZURA', 'FBYD', 'PROP', 'CVKD',
#        'MIRA', 'SPGC', 'FSUN', 'CVB', 'ASPI', 'CTNT', 'ESLA', 'IROH',
#        'CDT', 'APGE', 'GEV', 'WODI', 'SPEC', 'ISPR', 'TRML', 'KVAC',
#        'RBRI', 'ATMU', 'NNAG', 'AITR', 'IPXX', 'ZEO', 'BOWN', 'ADVB',
#        'MSS', 'GENK', 'LQR', 'CPBI', 'NETD', 'RISE', 'GPAK', 'NCL',
#        'INHD', 'QETA', 'CLBR', 'TELO', 'BAYA', 'IBAC', 'LEGT', 'HLXB',
#        'BKHAU', 'NIDV', 'CCIXU'], dtype=object)

# %%
companies['Exchange'].value_counts()
# Out:
# Exchange
# NAS     338
# NYS      93
# PINX     40
# ASE      24
# TSX       6
# ASX       5
# NEOE      4
# OTC       3
# CNQ       2
# OSL       2
# TSE       2
# LON       2
# KRX       1
# STU       1
# GREY      1
# ROCO      1
# BATS      1
# Name: count, dtype: int64

# %%
companies['BusinessStatus'].unique()
# Out:
# array(['Profitable', 'Generating Revenue',
#        'Generating Revenue/Not Profitable', 'Bankruptcy: Admin/Reorg',
#        'Clinical Trials - Phase 3', 'Clinical Trials - Phase 2',
#        'Bankruptcy: Liquidation', 'Clinical Trials - General',
#        'Clinical Trials - Phase 1', 'Pre-Clinical Trials', None,
#        'Out of Business', 'Clinical Trials - Phase 4',
#        'Product In Beta Test', 'Product Development', 'Stealth',
#        'Startup', 'Restart'], dtype=object)

# %%
companies['OwnershipStatus'].unique()
# Out:
# array(['Privately Held (backing)', 'Publicly Held',
#        'Acquired/Merged (Operating Subsidiary)', 'Acquired/Merged',
#        'In IPO Registration', 'Privately Held (no backing)',
#        'Out of Business'], dtype=object)

# %%
companies['CompanyFinancingStatus'].value_counts()
# Out:
# CompanyFinancingStatus
# Venture Capital-Backed                   4130
# Private Equity-Backed                     709
# Corporate Backed or Acquired              560
# Formerly VC-backed                        405
# Corporation                               266
# Formerly PE-Backed                        230
# Pending Transaction (M&A)                  74
# Pending Transaction (PE)                   36
# Pending Transaction (VC)                   28
# Failed Transaction (M&A)                   12
# Private Debt Financed                      10
# Formerly Angel backed                      10
# Angel-Backed                                6
# Formerly Accelerator/Incubator backed       5
# Formerly Private Debt Financed              2
# Accelerator/Incubator Backed                2
# Failed Transaction (VC)                     2
# Name: count, dtype: int64

# %%
deals['SiteLocation'].nunique()
# Out:
# 1522

# %%
companies['FinancingStatusNote'].unique()
# Out:
# array(['The company was acquired by American Industrial Partners through a $371 million LBO on April 10, 2024 through a public-to-private transaction. Through the acquisition, the company strengthens its position in partnership with company management by deploying AIP skills across areas including product engineering, aftermarket, procurement, quality systems, logistics, LEAN, IT, and finance.',
#        "The company was acquired by Mizuho Americas for $550 million on December 1, 2023. The acquisition adds complementary services to Mizuho's existing capital markets, banking and private capital advisory capabilities across the corporate and investment bank.",
#        'The company raised $12.20 million of venture funding from undisclosed investors on September 5, 2023.',
#        ...,
#        "The company closed on $8 million of an undisclosed targeted amount of seed funding in a deal led by Hack VC and Polychain Capital on May 1, 2024, putting the company's pre-money valuation at $72 million. Previously ,the company closed on $10 million of an undisclosed targeted amount of venture funding from Anatoly Yakovenko on May 1, 2024. Other undisclosed investors also participated in the round.",
#        'The company raised $15.68 million of venture funding from undisclosed investors on April 26, 2024.',
#        'The company raised $8 million of venture funding from Florida Opportunity Fund on March 26, 2024.'],
#       dtype=object)

# %%
companies.columns
# Out:
# Index(['CompanyName', 'CompanyAlsoKnownAs', 'CompanyFormerName',
#        'CompanyLegalName', 'Description', 'Keywords', 'CompanyFinancingStatus',
#        'CompanyFinancingStatusDate', 'TotalRaised', 'TotalRaisedNativeAmount',
#        'TotalRaisedNativeCurrency', 'BusinessStatus', 'BusinessStatusDate',
#        'OwnershipStatus', 'OwnershipStatusDate', 'Universe', 'Website',
#        'Employees', 'EmployeeAsOfDate', 'DescriptionShort', 'Exchange',
#        'Ticker', 'YearFounded', 'ParentCompany', 'ParentCompanyID',
#        'FinancingStatusNote', 'FinancingStatusNoteAsOfDate',
#        'FacebookProfileURL', 'TwitterProfileURL', 'LinkedInProfileURL',
#        'PrimaryContactPBId', 'PrimaryContactFirstName',
#        'PrimaryContactLastName', 'PrimaryContactMiddle',
#        'PrimaryContactPrefix', 'PrimaryContactSuffix', 'PrimaryContact',
#        'PrimaryContactTitle', 'RowID', 'LastUpdated'],
#       dtype='object')

# %%
deals['Debts'].isna().sum()
# Out:
# 24737

# %%
deals['DebtRaisedInRound'].isna().sum()
# Out:
# 26147

# %%
deals.columns
# Out:
# Index(['CompanyID', 'CompanyName', 'DealNo', 'DealDate', 'AnnouncedDate',
#        'DealSize', 'DealStatus', 'DealSizeStatus', 'PremoneyValuation',
#        'PostValuation', 'PostValuationStatus', 'PercentAcquired',
#        'RaisedToDate', 'VCRound', 'VCRoundUp_Down_Flat',
#        'TotalInvestedCapital', 'InvestorOwnership', 'StockSplit', 'DealType',
#        'DealType2', 'DealType3', 'DealClass', 'DealSynopsis',
#        'NativeCurrencyOfDeal', 'TotalInvestedEquity', 'AddOn', 'AddOnSponsors',
#        'AddOnPlatform', 'TotalNewDebt', 'Debts', 'DebtRaisedInRound',
#        'ContingentPayout', 'Employees', 'BusinessStatus', 'FinancingStatus',
#        'SiteLocation', 'ExitScope', 'RowID', 'LastUpdated'],
#       dtype='object')

# %%
deals[deals['Debts'].isna()][['Debts', 'DebtRaisedInRound', 'TotalNewDebt']]
# Out:
#            Debts  DebtRaisedInRound  TotalNewDebt
# DealID
# 247042-45T  None                NaN           NaN
# 256383-64T  None                NaN           NaN
# 256415-23T  None                NaN           NaN
# 248160-07T  None                NaN           NaN
# 255261-25T  None                NaN           NaN
# ...          ...                ...           ...
# 71551-18T   None                NaN           NaN
# 195103-18T  None                NaN           NaN
# 100754-65T  None                NaN           NaN
# 124154-29T  None                NaN           NaN
# 60266-26T   None                NaN           NaN
#
# [24737 rows x 3 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(deals[deals['Debts'].isna()][['Debts', 'DebtRaisedInRound', 'TotalNewDebt']].isnull(), cbar=True)
plt.title('Heatmap of Missing Values for Companies')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
deals[(deals['Debts'].isna()) & deals['DebtRaisedInRound'].isna()][['Debts', 'DebtRaisedInRound', 'TotalNewDebt', 'FinancingStatus']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 deals[(deals['Debts'].isna()) & deals['DebtRaisedInRound'].isna()][['Debts', 'DebtRaisedInRound', 'TotalNewDebt', 'FinancingStatus', 'Universe']]
#
# File ~/miniforge3/envs/myenv/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniforge3/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Universe'] not in index"

# %%
deals[deals['DebtRaisedInRound']==0][['Debts', 'DebtRaisedInRound', 'TotalNewDebt']]
# Out:
#            Debts  DebtRaisedInRound  TotalNewDebt
# DealID
# 243870-85T  None                0.0           NaN
# 219499-66T  None                0.0           NaN
# 168245-65T  None                0.0           NaN
